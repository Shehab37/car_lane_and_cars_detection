# %% [markdown]
# <a href="https://colab.research.google.com/github/Shehab37/self-driving-perception-stack/blob/main/yolov5_cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-229-g09ba6f6 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
# upload the videos in yolov5 dir

# %%
# !python detect.py --source challenge_video.mp4  # video
# Out:
# detect: weights=yolov5s.pt, source=challenge_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-229-g09ba6f6 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/484) /content/yolov5/challenge_video.mp4: 384x640 3 cars, Done. (0.018s)
# video 1/1 (2/484) /content/yolov5/challenge_video.mp4: 384x640 3 cars, Done. (0.012s)
# video 1/1 (3/484) /content/yolov5/challenge_video.mp4: 384x640 3 cars, Done. (0.012s)
# video 1/1 (4/484) /content/yolov5/challenge_video.mp4: 384x640 3 cars, Done. (0.012s)
# ...

# %%
# !python detect.py --source project_video.mp4  # video
# Out:
# detect: weights=yolov5s.pt, source=project_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-229-g09ba6f6 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/1260) /content/yolov5/project_video.mp4: 384x640 1 potted plant, Done. (0.018s)
# video 1/1 (2/1260) /content/yolov5/project_video.mp4: 384x640 Done. (0.013s)
# video 1/1 (3/1260) /content/yolov5/project_video.mp4: 384x640 Done. (0.011s)
# video 1/1 (4/1260) /content/yolov5/project_video.mp4: 384x640 1 potted plant, Done. (0.012s)
# ...

# %%
# !python detect.py --source harder_challenge_video.mp4
# Out:
# detect: weights=yolov5s.pt, source=harder_challenge_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-229-g09ba6f6 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/1199) /content/yolov5/harder_challenge_video.mp4: 384x640 Done. (0.018s)
# video 1/1 (2/1199) /content/yolov5/harder_challenge_video.mp4: 384x640 Done. (0.017s)
# video 1/1 (3/1199) /content/yolov5/harder_challenge_video.mp4: 384x640 Done. (0.013s)
# video 1/1 (4/1199) /content/yolov5/harder_challenge_video.mp4: 384x640 Done. (0.011s)
# ...
